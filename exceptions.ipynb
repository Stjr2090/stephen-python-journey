# %% [markdown]
# <a href="https://colab.research.google.com/github/Stjr2090/stephen-python-journey/blob/main/exceptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
  x= get_it()
  print (F"")
def get_int():
while True:
  try:
    x= int (input("what's x? "))
  except ValueError:
    print ("x is not an integer")
  else:
    return x
# Out:
# what's x? cat
# x is not an integer
# what's x? 50
# x is 50
