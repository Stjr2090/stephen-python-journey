# %% [markdown]
# <a href="https://colab.research.google.com/github/Stjr2090/stephen-python-journey/blob/main/CONDITIONALS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= int(input("what's x)"))
y= int(input ("what's y"))

if x < y:
    print("x is less than Y")

elif x > y:
  print("is greater than y")

else:
  print("x is equal to y")
# Out:
# what's x)5
# what's y9
# x is less than Y

# %%
y= int(input ("what's y)"))
x= int (input ("what's x"))

if x!=y:
  print("x is not equal to y")
else:
  print ("X is equal to y")
# Out:
# what's y)6
# what's x9
# x is not equal to y

# %%
score = int(input ("score: "))
if score>= 90 and score<=100:
  print ("Grade: A")
elif score >=80 and score <90:
  print ("Grade:B")
elif score>= 70< 80:
  print ("Grade: C")
elif score >=60:
  print ("Grade: D")
else:
  print ("Grade F")
# Out:
# score: 95
# Grade: A

# %%
def main():
  x= int(input("What's X"))
  if is_even (x):
    print("even")
  else:
    print("Odd")

def is_even(n):
  return n%2 == 0

main()
# Out:
# What's X2
# even

# %%
name = input ("what's your name")
match name:
  case "Harry" | "Hermoine"|"Ron":
    print ("Griffindor")
  case "Jane"| "Jake":
    print ("HOUSE 2")
  case _:
    print ("who")
# Out:
# what's your nameJames
# who
